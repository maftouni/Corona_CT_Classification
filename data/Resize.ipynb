# %%
from PIL import Image
from skimage import io



import cv2
import glob
all_images=glob.glob("training/1noncorona/*.png")+glob.glob("training/1noncorona/*.jpg")
print(len(all_images))
# Out:
# 256

# %%
j=0
for i in range(len(all_images)):
    
    #img = Image.open(all_images[i]).convert('RGB')
    img=cv2.imread(all_images[i])
    img2=cv2.resize(img,(256,256),interpolation = cv2.INTER_AREA)
    #cv2.imwrite('validation_32/1noncorona/noncorona'+ '%02.0f' % j +'.jpg',img2)
    #j += 1
    cv2.imwrite(all_images[i],img2)

    #img.save(all_images[i])
    #img2=io.imread(all_images[i])
    print(img2.shape)
# Out:
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# ...
